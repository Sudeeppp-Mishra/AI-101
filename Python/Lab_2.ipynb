# %%
# string
a = "Hello World"
b = 'Hello World'
c = '''Hello WOrld'''
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
a = "Hello "
b = "World"
c = a+b
print(c)
# Out:
# Hello World

# %%
a = "Hello World\n"
print(a*2)
# Out:
# Hello World
# Hello World

# %%
for i in a:
    print(i, end="")
# Out:
# Hello World

# %%
a = input("Enter a = ")
print(a)
# Out:
# Hiiiiii

# %%
a = input("Enter a = ")
print(a)
# Out:
# Hiiii hellooooo

# %%
a = "Hello World"
a[2]
# Out:
# 'l'

# %%
a = "Hello World"
a[0:8]
# Out:
# 'Hello Wo'

# %%
a = "Hello World"
a[0:8:2]
# Out:
# 'HloW'

# %%
a = "Hello World"
a = len(a)
a
# Out:
# 11

# %%
a = "Hello World"
a[0::1] # a[-1::-1]
# Out:
# 'Hello World'

# %%
name = "Ram"
age = 23
add = "Kathmandu"
info = "Hello World I am "+name+"I am from"+add+" I am"+str(age)
print(info)
# Out:
# Hello World I am RamI am fromKathmandu I am23

# %%
name = input("Enter name = ")
age = int(input("Enter age = "))
add = input("Enter add = ")

info = f"Hello world I am {name}. I am from {add}. I am {age}" # f means Formatted string literals, for expression { }
print(info)
# Out:
# Hello world I am Ram. I am from Ktm. I am 19

# %%
s = 0
bill = str()
n = int(input("Enter n = "))
for i in range(n):
    name = input("Enter name = ")
    price = int(input("Enter price = "))
    quantity = int(input("Enter quantity = "))
    total=price*quantity
    bill = bill + f"{name} {price} {quantity} {total}\n"
    s = s+total
    
print("\nall total = ",s)
print(bill)
# Out:
# all total =  1910
# Tomato 160 1 160
# Strawberry 350 5 1750

# %%
a = "Ram Shyam Hari Sita Gita Ram"
if "Ram" in a:
    print("There is Ram")
else:
    print("No")
# Out:
# There is Ram

# %%
a = "Ram Shyam Hari Sita Gita Ram"
b = input("Enter search value = ")
if b in a:
    print(" Yes there is",b)
    print(a.count(b))
else:
    print("No")
# Out:
#  Yes there is Hari
# 1

# %%
#check without case sensitivity
a = "Ram Shyam Hari Sita Gita Ramesh".lower()
b = input("Enter search value = ").lower()
if b in a:
    print(" Yes there is",b)
    print(a.count(b))
else:
    print("No")
# Out:
#  Yes there is ramesh
# 1

# %%
a = "Ram Shyam Hari Sita Gita Ram"
print(a.lower())
print(a.upper())
print(a)
# Out:
# ram shyam hari sita gita ram
# RAM SHYAM HARI SITA GITA RAM
# Ram Shyam Hari Sita Gita Ram

# %%
a = input("Enter any no = ")
b = input("Enter next no = ")
if a == b[::-1]:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
# replace
a = "Ram Shyam Hari Sita Gita Ram"
b = a.replace('Ram','Nabin')
print(a)
# Out:
# Ram Shyam Hari Sita Gita Ram

# %%
print(b)
# Out:
# Nabin Shyam Hari Sita Gita Nabin

# %%
# FUNCTIONS
# pre-defined function - print(), type(), int(), str(), float(), bool(), input()

# user defined function
# def <function_name>():
#       <operations>
# function_name()

a = 10 # global var

def hello():
    print("Hello WOrld")
    
hello()
hello()
# Out:
# Hello WOrld
# Hello WOrld

# %%
def cal():
    l = int(input("Enter l = ")) # local var
    b = int(input("Enter b = ")) # local var
    a = l*b
    print(a)
    
cal()
# Out:
# 600

# %%
def cal():
    a = l*b
    print(a)
    
l = int(input("Enter l = ")) # global var
b = int(input("Enter b = ")) # global var
cal()
# Out:
# 15

# %%
# argument return type
# function without argument and no return type
# function with argument and no return type
# function without argument and return type
# function with argument and return type

# function without argument and no return type
def cal():
    a = l*b
    print(a)
    
l = int(input("Enter l = ")) # global var
b = int(input("Enter b = ")) # global var
cal()
# Out:
# 20

# %%
#function with argument and no return type
def cal(l,b):    #parameter
    a = l*b
    print(a)
    
l = int(input("Enter l = ")) #global variable
b = int(input("Enter b = ")) #global variable 
cal(l,b)   #argument
# Out:
# 20

# %%
#function with argument and no return type
def cal(x,y):    #parameter
    a = x*y
    print(a)
    
l = int(input("Enter l = ")) #global variable
b = int(input("Enter b = ")) #global variable 
cal(l,b)   #argument
# Out:
# 40

# %%
#function with argument and no return type
def area(x,y):    #parameter
    a = x*y
    print(a)
    
def volume(x,y,z):
    v = x*y*z
    print(v)
    
l = int(input("Enter l = ")) #global variable
b = int(input("Enter b = ")) #global variable
h = int(input("Enter h = ")) #global variable
area(l,b)   #argument
volume(l,b,h)
# Out:
# 24
# 24

# %%
#default argument
def language(lan = "Python"):
    print(lan)
    
language("C")
language("C++")
language("Python")
language()
# Out:
# C
# C++
# Python
# Python

# %%
# Return type function
def hello():
    return "Hello"
    
x = hello()
print(x)
# Out:
# Hello

# %%
# Return type function
def hello():
    return "Hello"
    
x = hello()

print(x+"World")
# Out:
# HelloWorld

# %%
# function with argument and return type

def area(x,y):
    a = x*y
    return a

l = int(input("Enter l = "))
b = int(input("Enter b = "))
h = int(input("Enter h = "))

ar = area(l,b)
v = ar*h
print("Volume = ",v)
# Out:
# Volume =  90

# %%
def area(x, y):
    a = x*y
    return a

def volume(x, y, z):
    ar = area(l,b)
    v = ar*h
    return v

l = int(input("Enter l = "))
b = int(input("Enter b = "))
h = int(input("Enter h = "))

vo = volume(l,b,h)
ar = area(l,b)
print("Volume = ", vo)
# Out:
# Volume =  120

# %%
# function with argument and return type

def cal(x,y,z):
    a = x*y
    v = a*z
    return a,v

l = int(input("Enter l = "))
b = int(input("Enter b = "))
h = int(input("Enter h = "))

av = cal(l,b,h)

print(av)
# Out:
# (200, 400)

# %%
area, volume = av
print(area, volume)
# Out:
# 200 400

# %%
a = 10, 20, 30
print(a)
# Out:
# (10, 20, 30)

# %%
def hello():
    print("Hello")
    hello()
    
hello()
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# ...

# %%
def cal():
    p = int(input("Enter p = "))
    t = float(input("Enter t = "))
    r = float(input("Enter r = "))
    i = p*t*r/100
    print(i)
    x = input("Press Enter for more cal")
    if x == "":
        cal()
        
cal()
# Out:
# 0.15
# 4.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 11
#       8     if x == "":
#       9         cal()
# ---> 11 cal()
#
# Cell In[45], line 9, in cal()
#       7 x = input("Press Enter for more cal")
#       8 if x == "":
# ----> 9     cal()
#
# Cell In[45], line 9, in cal()
#       7 x = input("Press Enter for more cal")
#       8 if x == "":
# ----> 9     cal()
#
# Cell In[45], line 2, in cal()
#       1 def cal():
# ----> 2     p = int(input("Enter p = "))
#       3     t = float(input("Enter t = "))
#       4     r = float(input("Enter r = "))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
tuple
# -indexing
# -ordered
# -Multiple and duplicate value
# -Imutable
# Out:
# tuple

# %%
a = tuple()
t = ("apple", "ball", "cat", "dog")
r = (1, 2, 3, 4, 5, 6, 7, 8, 9)
print(type(t))
print(type(r))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
a = ("Apple", )
print(type(a))
# Out:
# <class 'tuple'>

# %%
# no append() insert() extend()
# no update
# no del remove() pop()

a = ()
b = ("apple", )
d = ("ball",)
c = a+b+d
c
# Out:
# ('apple', 'ball')

# %%
n= int(input("Enter n = "))
l = ()
for i in range(n):
    x = int(input("Enter x = "))
    l = l+(x,)
    
print(l)
# Out:
# (3, 4, 5, 5, 3, 3, 5, 6, 3, 4)

# %%
a = 123, 34, 456, 2, 546, 324,
a
# Out:
# (123, 34, 456, 2, 546, 324)

# %%
# sum() ma() min() index()
a = (123, 34, 456, 2, 546, 324)
b = list(a)
b
# Out:
# [123, 34, 456, 2, 546, 324]

# %%
a = (123, 34, 456, 2, 546, 324)
b = list(a)
del b[0]
print(b)
# Out:
# [34, 456, 2, 546, 324]
